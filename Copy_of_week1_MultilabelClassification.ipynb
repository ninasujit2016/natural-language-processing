# %% [markdown]
# <a href="https://colab.research.google.com/github/ninasujit2016/natural-language-processing/blob/master/Copy_of_week1_MultilabelClassification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# *italicized text*# Predict tags on StackOverflow with linear models

# %% [markdown]
# In this assignment you will learn how to predict tags for posts from [StackOverflow](https://stackoverflow.com). To solve this task you will use multilabel classification approach.
#
# ### Libraries
#
# In this task you will need the following libraries:
# - [Numpy](http://www.numpy.org) — a package for scientific computing.
# - [Pandas](https://pandas.pydata.org) — a library providing high-performance, easy-to-use data structures and data analysis tools for the Python
# - [scikit-learn](http://scikit-learn.org/stable/index.html) — a tool for data mining and data analysis.
# - [NLTK](http://www.nltk.org) — a platform to work with natural language.

# %% [markdown]
# ### Data
#
# The following cell will download all data required for this assignment into the folder `week1/data`.

# %%
! wget https://raw.githubusercontent.com/hse-aml/natural-language-processing/master/setup_google_colab.py -O setup_google_colab.py
import setup_google_colab
setup_google_colab.setup_week1()

import sys
sys.path.append("..")

from common.download_utils import download_week1_resources
download_week1_resources()

# %%
318/878
# Out:
# 0.3621867881548975

# %% [markdown]
# ### Grading
# We will create a grader instance below and use it to collect your answers. Note that these outputs will be stored locally inside grader and will be uploaded to platform only after running submitting function in the last part of this assignment. If you want to make partial submission, you can run that cell any time you want.

# %%
from grader import Grader

# %%
grader = Grader()

# %% [markdown]
# ### Text preprocessing

# %% [markdown]
# For this and most of the following assignments you will need to use a list of stop words. It can be downloaded from *nltk*:

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %% [markdown]
# In this task you will deal with a dataset of post titles from StackOverflow. You are provided a split to 3 sets: *train*, *validation* and *test*. All corpora (except for *test*) contain titles of the posts and corresponding tags (100 tags are available). The *test* set is provided for Coursera's grading and doesn't contain answers. Upload the corpora using *pandas* and look at the data:

# %%
from ast import literal_eval
import pandas as pd
import numpy as np

# %%
def read_data(filename):
    data = pd.read_csv(filename, sep='\t')
    data['tags'] = data['tags'].apply(literal_eval)
    return data

# %%
train = read_data('data/train.tsv')
validation = read_data('data/validation.tsv')
test = pd.read_csv('data/test.tsv', sep='\t')

# %%
train.head()
# Out:
#                                                title                  tags
# 0                How to draw a stacked dotplot in R?                   [r]
# 1  mysql select all records where a datetime fiel...          [php, mysql]
# 2             How to terminate windows phone 8.1 app                  [c#]
# 3  get current time in a specific country via jquery  [javascript, jquery]
# 4                      Configuring Tomcat to Use SSL                [java]

# %% [markdown]
# As you can see, *title* column contains titles of the posts and *tags* column contains the tags. It could be noticed that a number of tags for a post is not fixed and could be as many as necessary.

# %% [markdown]
# For a more comfortable usage, initialize *X_train*, *X_val*, *X_test*, *y_train*, *y_val*.

# %%
X_train, y_train = train['title'].values, train['tags'].values
X_val, y_val = validation['title'].values, validation['tags'].values
X_test = test['title'].values

# %%
print(X_train[:3])
y_train[:3]
# Out:
# ['How to draw a stacked dotplot in R?'
#  'mysql select all records where a datetime field is less than a specified value'
#  'How to terminate windows phone 8.1 app']
# array([list(['r']), list(['php', 'mysql']), list(['c#'])], dtype=object)

# %% [markdown]
# One of the most known difficulties when working with natural data is that it's unstructured. For example, if you use it "as is" and extract tokens just by splitting the titles by whitespaces, you will see that there are many "weird" tokens like *3.5?*, *"Flip*, etc. To prevent the problems, it's usually useful to prepare the data somehow. In this task you'll write a function, which will be also used in the other assignments.
#
# **Task 1 (TextPrepare).** Implement the function *text_prepare* following the instructions. After that, run the function *test_text_prepare* to test it on tiny cases and submit it to Coursera.

# %%
import re

# %%
REPLACE_BY_SPACE_RE = re.compile('[/(){}\[\]\|@,;]')
BAD_SYMBOLS_RE = re.compile('[^0-9a-z #+_]')
STOPWORDS = set(stopwords.words('english'))

def text_prepare(text):
    """
        text: a string
        
        return: modified initial string
    """
    text = text.lower()
    text = REPLACE_BY_SPACE_RE.sub(' ',text) # repalce those symbols by space in text
    text = BAD_SYMBOLS_RE.sub('',text) #  delete symbols which are in BAD_SYMBOLS_RE from text
    text = ' '.join([w for w in text.strip().split() if w not in STOPWORDS]).strip() # delete stopwords from text
    text = text.replace('  ',' ')
    return text

# %%
def test_text_prepare():
    examples = ["SQL Server - any equivalent of Excel's CHOOSE function?",
                "How to free c++ memory vector<int> * arr?"]
    answers = ["sql server equivalent excels choose function", 
               "free c++ memory vectorint arr"]
    for ex, ans in zip(examples, answers):
        if text_prepare(ex) != ans:
            return "Wrong answer for the case: '%s'" % ex
    return 'Basic tests are passed.'

# %%
print(test_text_prepare())
# Out:
# Basic tests are passed.

# %% [markdown]
# Run your implementation for questions from file *text_prepare_tests.tsv* to earn the points.

# %%
prepared_questions = []
for line in open('data/text_prepare_tests.tsv', encoding='utf-8'):
    line = text_prepare(line.strip())
    prepared_questions.append(line)
text_prepare_results = '\n'.join(prepared_questions)

grader.submit_tag('TextPrepare', text_prepare_results)
# Out:
# Current answer for task TextPrepare is:
#  sqlite php readonly
# creating multiple textboxes dynamically
# self one prefer javascript
# save php date...

# %% [markdown]
# Now we can preprocess the titles using function *text_prepare* and  making sure that the headers don't have bad symbols:

# %%
X_train = [text_prepare(x) for x in X_train]
X_val = [text_prepare(x) for x in X_val]
X_test = [text_prepare(x) for x in X_test]

# %%
print(X_train[:4])
print(y_train[:4])
# Out:
# ['draw stacked dotplot r', 'mysql select records datetime field less specified value', 'terminate windows phone 81 app', 'get current time specific country via jquery']
# [list(['r']) list(['php', 'mysql']) list(['c#'])
#  list(['javascript', 'jquery'])]

# %%
print(X_val[:2]); print(y_val[:3])
# Out:
# ['odbc_exec always fail', 'access base classes variable within child class']
# [list(['php', 'sql']) list(['javascript']) list(['ruby-on-rails', 'ruby'])]

# %% [markdown]
# For each tag and for each word calculate how many times they occur in the train corpus.
#
# **Task 2 (WordsTagsCount).** Find 3 most popular tags and 3 most popular words in the train data and submit the results to earn the points.

# %%
# Dictionary of all tags from train corpus with their counts.
tags_counts = {}
# Dictionary of all words from train corpus with their counts.
words_counts = {}

######################################
######### YOUR CODE HERE #############
######################################
y_train_list=y_train.tolist()
taglist=[t for y in y_train_list for t in y]
from collections import Counter
tagsCounter=Counter(taglist)
tags_counts = {token:count for token,count in tagsCounter.items()}
wordsCounter = Counter(' '.join(X_train).strip().split())
words_counts = {token:count for token,count in wordsCounter.items()}

# %%
taglist[:10]
# Out:
# ['r',
#  'php',
#  'mysql',
#  'c#',
#  'javascript',
#  'jquery',
#  'java',
#  'ruby-on-rails',
#  'ruby',
#  'ruby-on-rails-3']

# %% [markdown]
# We are assuming that *tags_counts* and *words_counts* are dictionaries like `{'some_word_or_tag': frequency}`. After applying the sorting procedure, results will be look like this: `[('most_popular_word_or_tag', frequency), ('less_popular_word_or_tag', frequency), ...]`. The grader gets the results in the following format (two comma-separated strings with line break):
#
#     tag1,tag2,tag3
#     word1,word2,word3
#
# Pay attention that in this assignment you should not submit frequencies or some additional information.

# %%
most_common_tags = sorted(tags_counts.items(), key=lambda x: x[1], reverse=True)[:3]
most_common_words = sorted(words_counts.items(), key=lambda x: x[1], reverse=True)[:3]

grader.submit_tag('WordsTagsCount', '%s\n%s' % (','.join(tag for tag, _ in most_common_tags), 
                                                ','.join(word for word, _ in most_common_words)))
# Out:
# Current answer for task WordsTagsCount is:
#  javascript,c#,java
# using,php,java...

# %%
common_words_dict = {token:index for token, index in enumerate(sorted(word for word,count in most_common_words))}
common_tags_dict = {tag:index for tag,index in enumerate(sorted(tag for tag,count in most_common_tags))}
common_tags_dict
# Out:
# {0: 'c#', 1: 'java', 2: 'javascript'}

# %% [markdown]
# ### Transforming text to a vector
#
# Machine Learning algorithms work with numeric data and we cannot use the provided text data "as is". There are many ways to transform text data to numeric vectors. In this task you will try to use two of them.
#
# #### Bag of words
#
# One of the well-known approaches is a *bag-of-words* representation. To create this transformation, follow the steps:
# 1. Find *N* most popular words in train corpus and numerate them. Now we have a dictionary of the most popular words.
# 2. For each title in the corpora create a zero vector with the dimension equals to *N*.
# 3. For each text in the corpora iterate over words which are in the dictionary and increase by 1 the corresponding coordinate.
#
# Let's try to do it for a toy example. Imagine that we have *N* = 4 and the list of the most popular words is
#
#     ['hi', 'you', 'me', 'are']
#
# Then we need to numerate them, for example, like this:
#
#     {'hi': 0, 'you': 1, 'me': 2, 'are': 3}
#
# And we have the text, which we want to transform to the vector:
#
#     'hi how are you'
#
# For this text we create a corresponding zero vector
#
#     [0, 0, 0, 0]
#
# And iterate over all words, and if the word is in the dictionary, we increase the value of the corresponding position in the vector:
#
#     'hi':  [1, 0, 0, 0]
#     'how': [1, 0, 0, 0] # word 'how' is not in our dictionary
#     'are': [1, 0, 0, 1]
#     'you': [1, 1, 0, 1]
#
# The resulting vector will be
#
#     [1, 1, 0, 1]
#
# Implement the described encoding in the function *my_bag_of_words* with the size of the dictionary equals to 5000. To find the most common words use train data. You can test your code using the function *test_my_bag_of_words*.

# %%
DICT_SIZE = 5000
common_words = sorted(words_counts.items(), key=lambda x: x[1], reverse=True)[:DICT_SIZE]
WORDS_TO_INDEX = {word:i for i, word in enumerate(sorted(word for word,c in common_words))} #### YOUR CODE HERE ###
INDEX_TO_WORDS = {i:word for i, word in enumerate(sorted(word for word,c in common_words))} #### YOUR CODE HERE #####
ALL_WORDS = WORDS_TO_INDEX.keys()

def my_bag_of_words(text, words_to_index, dict_size):
    """
        text: a string
        dict_size: size of the dictionary
        
        return a vector which is a bag-of-words representation of 'text'
    """
    result_vector = np.zeros(dict_size)
    # YOUR CODE HERE 
    for word in text.strip().split():
        if word in words_to_index:
              result_vector[words_to_index[word]]=1
    return result_vector

# %%
words_to_index = {'hi': 0, 'you': 1, 'me': 2, 'are': 3}
examples = ['hi how are you']
my_bag_of_words(examples[0], words_to_index, 4) 
#result_vector.shape
# Out:
# array([1., 1., 0., 1.])

# %%
list(common_words)[:3]
# Out:
# [('using', 8278), ('php', 5614), ('java', 5501)]

# %%
def test_my_bag_of_words():
    words_to_index = {'hi': 0, 'you': 1, 'me': 2, 'are': 3}
    examples = ['hi how are you']
    answers = [[1, 1, 0, 1]]
    for ex, ans in zip(examples, answers):
        if (my_bag_of_words(ex, words_to_index, 4) != ans).any():
            return "Wrong answer for the case: '%s'" % ex
    return 'Basic tests are passed.'

# %%
print(test_my_bag_of_words())
# Out:
# Basic tests are passed.

# %% [markdown]
# Now apply the implemented function to all samples (this might take up to a minute):

# %%
from scipy import sparse as sp_sparse

# %%
X_train_mybag = sp_sparse.vstack([sp_sparse.csr_matrix(my_bag_of_words(text, WORDS_TO_INDEX, DICT_SIZE)) for text in X_train])
X_val_mybag = sp_sparse.vstack([sp_sparse.csr_matrix(my_bag_of_words(text, WORDS_TO_INDEX, DICT_SIZE)) for text in X_val])
X_test_mybag = sp_sparse.vstack([sp_sparse.csr_matrix(my_bag_of_words(text, WORDS_TO_INDEX, DICT_SIZE)) for text in X_test])
print('X_train shape ', X_train_mybag.shape)
print('X_val shape ', X_val_mybag.shape)
print('X_test shape ', X_test_mybag.shape)
# Out:
# X_train shape  (100000, 5000)
# X_val shape  (30000, 5000)
# X_test shape  (20000, 5000)

# %% [markdown]
# As you might notice, we transform the data to sparse representation, to store the useful information efficiently. There are many [types](https://docs.scipy.org/doc/scipy/reference/sparse.html) of such representations, however sklearn algorithms can work only with [csr](https://docs.scipy.org/doc/scipy/reference/generated/scipy.sparse.csr_matrix.html#scipy.sparse.csr_matrix) matrix, so we will use this one.

# %% [markdown]
# **Task 3 (BagOfWords).** For the 11th row in *X_train_mybag* find how many non-zero elements it has. In this task the answer (variable *non_zero_elements_count*) should be an integer number, e.g. 20.

# %%
row = X_train_mybag[10].toarray()[0]
non_zero_elements_count = (row > 0).sum() ####### YOUR CODE HERE #######

grader.submit_tag('BagOfWords', str(non_zero_elements_count))
# Out:
# Current answer for task BagOfWords is:
#  7...

# %%
row = X_train_mybag[10].toarray()[0]

# %%
type(X_train_mybag[10].toarray()[0])
# Out:
# numpy.ndarray

# %%
row[:4,]
# Out:
# array([0., 0., 0., 0.])

# %% [markdown]
# #### TF-IDF
#
# The second approach extends the bag-of-words framework by taking into account total frequencies of words in the corpora. It helps to penalize too frequent words and provide better features space.
#
# Implement function *tfidf_features* using class [TfidfVectorizer](http://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfVectorizer.html) from *scikit-learn*. Use *train* corpus to train a vectorizer. Don't forget to take a look into the arguments that you can pass to it. We suggest that you filter out too rare words (occur less than in 5 titles) and too frequent words (occur more than in 90% of the titles). Also, use bigrams along with unigrams in your vocabulary.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
def tfidf_features(X_train, X_val, X_test):
    """
        X_train, X_val, X_test — samples        
        return TF-IDF vectorized representation of each sample and vocabulary
    """
    # Create TF-IDF vectorizer with a proper parameters choice
    # Fit the vectorizer on the train set
    # Transform the train, test, and val sets and return the result
    
    
    tfidf_vectorizer = TfidfVectorizer(min_df=5,max_df=0.9,ngram_range=(1, 2),token_pattern='(\S+)') ####### YOUR CODE HERE #######
    X_train0 = tfidf_vectorizer.fit_transform(X_train)
    X_val0 = tfidf_vectorizer.transform(X_val)
    X_test0 = tfidf_vectorizer.transform(X_test)
 
    return X_train0, X_val0, X_test0, tfidf_vectorizer.vocabulary_

# %%
X_train_tfidf, X_val_tfidf, X_test_tfidf, tfidf_vocab = tfidf_features(X_train, X_val, X_test)
tfidf_reversed_vocab = {i:word for word,i in tfidf_vocab.items()}

# %%
'c++' in list(tfidf_vocab.keys())
print(tfidf_vocab['php'])
print(tfidf_vocab['c++'])

type(X_train_tfidf)
# Out:
# 11729
# 1976
# scipy.sparse.csr.csr_matrix

# %%
tfidf_reversed_vocab[1976]
# Out:
# 'c++'

# %%
tfidf_reversed_vocab[11729]
# Out:
# 'php'

# %%
X_train[0]
# Out:
# 'draw stacked dotplot r'

# %% [markdown]
# Once you have done text preprocessing, always have a look at the results. Be very careful at this step, because the performance of future models will drastically depend on it.
#
# In this case, check whether you have c++ or c# in your vocabulary, as they are obviously important tokens in our tags prediction task:

# %% [markdown]
# Now, use this transormation for the data and check again.

# %% [markdown]
# ### MultiLabel classifier
#
# As we have noticed before, in this task each example can have multiple tags. To deal with such kind of prediction, we need to transform labels in a binary form and the prediction will be a mask of 0s and 1s. For this purpose it is convenient to use [MultiLabelBinarizer](http://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.MultiLabelBinarizer.html) from *sklearn*.

# %%
from sklearn.preprocessing import MultiLabelBinarizer

# %%
classes=sorted(tags_counts.keys())
len(classes)
# Out:
# 100

# %%
mlb = MultiLabelBinarizer(classes=sorted(tags_counts.keys()))
y_train = mlb.fit_transform(y_train)
y_val = mlb.fit_transform(y_val)

# %%
len([i for i,x in enumerate(y_train) if (x>0).sum()>0])
# Out:
# 100000

# %% [markdown]
# Implement the function *train_classifier* for training a classifier. In this task we suggest to use One-vs-Rest approach, which is implemented in [OneVsRestClassifier](http://scikit-learn.org/stable/modules/generated/sklearn.multiclass.OneVsRestClassifier.html) class. In this approach *k* classifiers (= number of tags) are trained. As a basic classifier, use [LogisticRegression](http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html). It is one of the simplest methods, but often it performs good enough in text classification tasks. It might take some time, because a number of classifiers to train is large.

# %% [markdown]
# If you can't find it, we need to understand how did it happen that we lost them? It happened during the built-in tokenization of TfidfVectorizer. Luckily, we can influence on this process. Get back to the function above and use '(\S+)' regexp as a *token_pattern* in the constructor of the vectorizer.

# %%
from sklearn.multiclass import OneVsRestClassifier
from sklearn.linear_model import LogisticRegression, RidgeClassifier, RidgeClassifierCV,LogisticRegression
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.neural_network import MLPClassifier
#from sklearn.decomposition.nmf import NMF
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import AdaBoostClassifier
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.decomposition.nmf module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.decomposition. Anything that cannot be imported from sklearn.decomposition is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
#from sklearn.preprocessing import StandardScaler
#scaler=StandardScaler(with_mean=False)
#XData=scaler.fit_transform(X_train_mybag)

# %%
def train_classifier(X_train, y_train):
    """
      X_train, y_train — training data
      
      return: trained classifier
    """
    
    # Create and fit LogisticRegression wraped into OneVsRestClassifier.
    ######### YOUR CODE HERE #############
    #from sklearn.preprocessing import StandardScaler
    #scaler= StandardScaler(with_mean=False)
    #clf = OneVsRestClassifier(RidgeClassifierCV(alphas=[1e-3, 1e-2, 1e-1, 1],normalize=True)).fit(X_train, y_train)
    #clf = OneVsRestClassifier(RidgeClassifier(alpha=0.5, normalize=True,solver='sparse_cg',max_iter=1000)).fit(X_train, y_train)
    clf = OneVsRestClassifier(LogisticRegression(max_iter=2000,multi_class='ovr',solver='saga',penalty='l1',C=0.8)).fit(X_train, y_train)
    #clf = OneVsRestClassifier(RidgeClassifier(normalize=True))
    #clf.fit(X_train, y_train)
    #clf= OneVsRestClassifier(LogisticRegressionCV(cv=5, random_state=0)).fit(X_train, y_train)
    return clf

# %% [markdown]
# Train the classifiers for different data transformations: *bag-of-words* and *tf-idf*.

# %%
classifier_mybag = train_classifier(X_train_mybag, y_train)
classifier_tfidf = train_classifier(X_train_tfidf, y_train)

# %%
X_train_tfidf.shape
X_train_mybag[:,1:10]
# Out:
# <100000x9 sparse matrix of type '<class 'numpy.float64'>'
# 	with 882 stored elements in Compressed Sparse Row format>

# %% [markdown]
# Now you can create predictions for the data. You will need two types of predictions: labels and scores.

# %%
classifier_mybag = train_classifier(X_train_mybag, y_train)
classifier_tfidf = train_classifier(X_train_tfidf, y_train)

y_val_predicted_labels_mybag = classifier_mybag.predict(X_val_mybag)
y_val_predicted_scores_mybag = classifier_mybag.decision_function(X_val_mybag)

y_val_predicted_labels_tfidf = classifier_tfidf.predict(X_val_tfidf)
y_val_predicted_scores_tfidf = classifier_tfidf.decision_function(X_val_tfidf)

from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import roc_auc_score 
from sklearn.metrics import average_precision_score
from sklearn.metrics import recall_score

def print_evaluation_scores(y_val, predicted):
    
    ######### YOUR CODE HERE #############
    print(accuracy_score(y_val, predicted))
    print(f1_score(y_val, predicted, average='weighted'))
    print(average_precision_score(y_val, predicted))
print('Bag-of-words')
print_evaluation_scores(y_val, y_val_predicted_labels_mybag)
print('Tfidf')
print_evaluation_scores(y_val, y_val_predicted_labels_tfidf)

# %% [markdown]
# Now take a look at how classifier, which uses TF-IDF, works for a few examples:

# %%
y_val_pred_inversed = mlb.inverse_transform(y_val_predicted_labels_tfidf)
y_val_inversed = mlb.inverse_transform(y_val)
for i in range(3):
    print('Title:\t{}\nTrue labels:\t{}\nPredicted labels:\t{}\n\n'.format(
        X_val[i],
        ','.join(y_val_inversed[i]),
        ','.join(y_val_pred_inversed[i])
    ))
# Out:
# Title:	odbc_exec always fail
# True labels:	php,sql
# Predicted labels:
#
#
# Title:	access base classes variable within child class
# True labels:	javascript
# Predicted labels:
#
#
# Title:	contenttype application json required rails
# True labels:	ruby,ruby-on-rails
# Predicted labels:

# %%
y_val_pred_inversed[:10]
# Out:
# [(),
#  (),
#  ('json', 'ruby-on-rails'),
#  ('ruby',),
#  ('json', 'ruby-on-rails'),
#  (),
#  (),
#  (),
#  ('javascript', 'jquery'),
#  ('hibernate', 'java')]

# %% [markdown]
# Now, we would need to compare the results of different predictions, e.g. to see whether TF-IDF transformation helps or to try different regularization techniques in logistic regression. For all these experiments, we need to setup evaluation procedure.

# %% [markdown]
# ### Evaluation
#
# To evaluate the results we will use several classification metrics:
#  - [Accuracy](http://scikit-learn.org/stable/modules/generated/sklearn.metrics.accuracy_score.html)
#  - [F1-score](http://scikit-learn.org/stable/modules/generated/sklearn.metrics.f1_score.html)
#  - [Area under ROC-curve](http://scikit-learn.org/stable/modules/generated/sklearn.metrics.roc_auc_score.html)
#  - [Area under precision-recall curve](http://scikit-learn.org/stable/modules/generated/sklearn.metrics.average_precision_score.html#sklearn.metrics.average_precision_score)
#
# Make sure you are familiar with all of them. How would you expect the things work for the multi-label scenario? Read about micro/macro/weighted averaging following the sklearn links provided above.

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import roc_auc_score 
from sklearn.metrics import average_precision_score
from sklearn.metrics import recall_score

# %% [markdown]
# Implement the function *print_evaluation_scores* which calculates and prints to stdout:
#  - *accuracy*
#  - *F1-score macro/micro/weighted*
#  - *Precision macro/micro/weighted*

# %%
def print_evaluation_scores(y_val, predicted):
    
    ######### YOUR CODE HERE #############
    print(accuracy_score(y_val, predicted))
    print(f1_score(y_val, predicted, average='weighted'))
    print(average_precision_score(y_val, predicted))

# %%
print('Bag-of-words')
print_evaluation_scores(y_val, y_val_predicted_labels_mybag)
print('Tfidf')
print_evaluation_scores(y_val, y_val_predicted_labels_tfidf)
# Out:
# Bag-of-words
# 0.19253333333333333
# 0.39513724001842127
# 0.1220445071251969
# Tfidf
# 0.23703333333333335
# 0.48242121028526597
# 0.198577623133697

# %% [markdown]
# You might also want to plot some generalization of the [ROC curve](http://scikit-learn.org/stable/modules/model_evaluation.html#receiver-operating-characteristic-roc) for the case of multi-label classification. Provided function *roc_auc* can make it for you. The input parameters of this function are:
#  - true labels
#  - decision functions scores
#  - number of classes

# %%
from metrics import roc_auc
# %matplotlib inline

# %%
n_classes = len(tags_counts)
roc_auc(y_val, y_val_predicted_scores_mybag, n_classes)

# %%
n_classes = len(tags_counts)
roc_auc(y_val, y_val_predicted_scores_tfidf, n_classes)

# %% [markdown]
# **Task 4 (MultilabelClassification).** Once we have the evaluation set up, we suggest that you experiment a bit with training your classifiers. We will use *F1-score weighted* as an evaluation metric. Our recommendation:
# - compare the quality of the bag-of-words and TF-IDF approaches and chose one of them.
# - for the chosen one, try *L1* and *L2*-regularization techniques in Logistic Regression with different coefficients (e.g. C equal to 0.1, 1, 10, 100).
#
# You also could try other improvements of the preprocessing / model, if you want.

# %%
######################################
######### YOUR CODE HERE #############
######################################

# %% [markdown]
# When you are happy with the quality, create predictions for *test* set, which you will submit to Coursera.

# %%
test_predictions = classifier_tfidf.predict(X_test_tfidf) ######### YOUR CODE HERE #############
test_pred_inversed = mlb.inverse_transform(test_predictions)

test_predictions_for_submission = '\n'.join('%i\t%s' % (i, ','.join(row)) for i, row in enumerate(test_pred_inversed))
grader.submit_tag('MultilabelClassification', test_predictions_for_submission)
# Out:
# Current answer for task MultilabelClassification is:
#  0	php
# 1	javascript
# 2
# 3	javascript,jquery
# 4	android
# 5	php,xml
# 6	json
# 7	java
# 8	python
# 9
# 10
# 11
# 12
# ...

# %% [markdown]
# ### Analysis of the most important features

# %% [markdown]
# Finally, it is usually a good idea to look at the features (words or n-grams) that are used with the largest weigths in your logistic regression model.

# %% [markdown]
# Implement the function *print_words_for_tag* to find them. Get back to sklearn documentation on [OneVsRestClassifier](http://scikit-learn.org/stable/modules/generated/sklearn.multiclass.OneVsRestClassifier.html) and [LogisticRegression](http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html) if needed.

# %%
def print_words_for_tag(classifier, tag, tags_classes, index_to_words, all_words):
    """
        classifier: trained classifier
        tag: particular tag
        tags_classes: a list of classes names from MultiLabelBinarizer
        index_to_words: index_to_words transformation
        all_words: all words in the dictionary
        
        return nothing, just print top 5 positive and top 5 negative words for current tag
    """
    print('Tag:\t{}'.format(tag))
    
    # Extract an estimator from the classifier for the given tag.
    # Extract feature coefficients from the estimator. 
    
    ######################################
    ######### YOUR CODE HERE #############
    ######################################
    est = classifier.estimators_[tags_classes.index(tag)]
    top_positive_words =[index_to_words[index] for index in est.coef_.argsort().tolist()[0][-5:]] # top-5 words sorted by the coefficiens.
    top_negative_words = [index_to_words[index] for index in est.coef_.argsort().tolist()[0][5:]]# bottom-5 words  sorted by the coefficients.
    print('Top positive words:\t{}'.format(', '.join(top_positive_words)))
    print('Top negative words:\t{}\n'.format(', '.join(top_negative_words)))

# %%
print_words_for_tag(classifier_tfidf, 'c', mlb.classes, tfidf_reversed_vocab, ALL_WORDS)
print_words_for_tag(classifier_tfidf, 'c++', mlb.classes, tfidf_reversed_vocab, ALL_WORDS)
print_words_for_tag(classifier_tfidf, 'linux', mlb.classes, tfidf_reversed_vocab, ALL_WORDS)
# Out:
# Tag:	c
# Top positive words:	integer pointer, fscanf, kernel space, line c, c
# Top negative words:	char c++, struct c++, stored proc, c++ linked, c++ struct, pointers c++, heap corruption, udp packets, type specifier, compile c++, c# calling, parameter function, class struct, operator new, use undeclared, pointer c++, files c++, passing null, version java, wchar_t, program uses, serial data, conversion int, doubly linked, must constant, cpp file, files like, using cocoa, linux windows, token expected, programming using, python generate, current process, integer java, network programming, application linux, without waiting, odd numbers, list c++, c++ member, returning string, identifier string, syntax use, string objective, c++ passing, 0xc0000005, facing, pointer exception, argument supplied, code java, c++ pointer, read whole, java linux, using variables, linux command, format time, numbers c#, output error, 2gb, mouse pointer, nonconst, variables c++, declare global, type void, doubly, video stream, java programming, directory structure, code 1, rvalue, wait till, php linux, expected argument, way binding, implicit conversion, port communication, two digits, variable declared, library xcode, use opengl, standard input, windowsh, lpcstr, java finding, programming c++, concatenating two, element sequence, vector pointers, variable c++, get public, numbers python, recognized internal, error visual, string integers, postfix, compiler cant, variable error, fixed size, get memory, python linux, referenced assembly, large array, libraries c++, java socket, static vs, decimal precision, process memory, float c++, automatic reference, using format, running program, start c#, char string, real world, programming c#, create string, open failed, value first, strange behaviour, one character, int cannot, push_back, address client, status 1, javascript switch, c++ program, output array, nas, static_cast, cant compile, marshal, expression type, precompiled, c++ ubuntu, x function, mean stack, directory error, something else, file encoded, computation, opencv java, x lion, variables need, odbc driver, less size, calling python, difference static, project properties, much memory, raw data, failed exit, signal strength, program python, pixels image, uninitialized constant, finding number, array 2d, different length, number given, python without, separators, string buffer, using objective, string 2, modulus, c++ static, letter word, cannot accessed, fortran, method find, find substring, game using, decimal binary, stack trace, array characters, easier, c# program, depend, using jni, mainobject, file reading, recursive loop, wrong result, recursive method, missing type, fast way, code c++, console program, line php, number value, disk space, broken pipe, automating, size exceeded, socket error, somewhere, static const, capture output, python socket, variable object, applied operands, operands type, java switch, two separate, code visual, without converting, 0 key, return string, write program, pause resume, string hex, rangeerror, windows ce, socket connection, process exited, serial ports, optimized, two string, kill process, c++ exception, gaussian, copying data, lnk2019, symbol found, stdstring, receive data, variable referenced, connection could, made target, void method, unix timestamp, php socket, smtp connect, c++ source, use net, osx lion, java use, different lengths, number occurrences, natural language, socket closed, base type, program java, n number, specific number, 2010 c++, two numbers, c++ standard, user inputs, number integer, read first, game programming, enough space, stl container, java tcp, windows program, stdlist, method argument, sending large, one type, line 0, convert float, tree structure, 48, unknown size, arrays different, read contents, int c#, line 1, function convert, serversocket, target machine, list integers, string representation, decimal numbers, find header, condition variable, time different, cannot declare, 2 decimal, ifelse statements, grand central, central dispatch, multithreaded ...
#
# Tag:	c++
# Top positive words:	mfc, c++11, boostasio, qt, c++
# Top negative words:	pointers c, pointer c, find smallest, arrays c, java compiler, access memory, python opencv, c macro, c structs, 2010 project, __attribute__, call member, c# visual, vector r, command linux, allocated malloc, portable class, structures c, c preprocessor, studio c#, compiler errors, pyside, files like, opencv java, process exited, find largest, error x, type c, implicit declaration, type function, reading serial, interface member, mismatch cannot, linux kernel, struct c, bitwise operators, nonobject, strcmp, type reference, reduce memory, invalid token, print values, object without, point number, constructor found, code error, use unresolved, unresolved identifier, c linux, expected argument, way getting, integer pointer, port using, different size, allowed memory, type struct, list c, incompatible pointer, equals operator, nest, compile java, windows command, heap size, java store, invoke virtual, array ints, c# calling, operands type, applied operands, member type, external dll, constructor function, static constructor, stand alone, odbc driver, sorting algorithm, api calls, use net, accessing elements, usb device, c programming, methods using, pointer exception, rc, c source, time error, typecasting, dereferencing, realloc, interview question, two integers, nested functions, multiple projects, single variable, abc, illegal start, 1110, ubuntu 1110, thirdparty, + python, exactly 2, first n, fast way, create 2d, used another, referenced assignment, largest value, converting integer, generic error, occurred gdi+, even numbers, process linux, unsorted array, csharp, macho, initializing array, monodevelop, database visual, type name, c# dll, file file, c function, arguments c#, operator java, dimensional arrays, difference static, cannot invoke, invalid arguments, pointer struct, enemy, pointer char, string binary, points given, namespace declaration, converting int, type expression, executable jar, propertys, function prepare, unterminated string, types c, compile python, static class, cannot accessed, c extension, using user, exhausted, reference javascript, convert double, tree using, c# static, cython, conflicting types, defined type, occurrences substring, c# project, afterwards, convert hex, passed function, functions php, type exception, int float, namespace name, constructor class, store apps, integers using, visual basic, simple array, cs file, compile c, argument python, scene builder, java, whats easiest, variables functions, weird issue, super class, function vbnet, constructor java, message queue, rt, image found, intermittent, xcode project, del, expected expression, com port, integers strings, python user, working windows, c unix, function returning, control visual, kernel space, array 2d, code file, cannot assigned, operator cannot, warn, interface method, different functions, generic class, error multiple, string vs, finding number, using scanf, anonymous functions, find symbol, keyword argument, producer consumer, type namespace, swap two, enough space, byte string, pointer integer, testing using, vs function, c program, application net, constructor takes, contain constructor, abstract base, diagnostic, last n, takes exactly, eclipse debugger, one image, functions javascript, assembly reference, nonstatic field, name class, cannot used, mstest, set private, 1 given, committed, view template, resharper, error variable, advantages disadvantages, without visual, network adapter, whats equivalent, python, aes256, contour, line 0, convert c, static context, work eclipse, could initialize, java linux, files google, handle exception, screen using, c struct, whether string, vb 2010, subclass object, memory error, ex, 3rd party, web reference, util, class python, method child, python data, create function, methods static, using cocoa, matrix vector, usr local, less size, ascii string, must either, 0 0, descriptions, bigo, initialized error, using recursive, sending receiving, using single, tcp sockets ...
#
# Tag:	linux
# Top positive words:	linux using, linux c, command linux, linux, kernel space
# Top negative words:	python 25, able run, subprocess module, multiple child, shared memory, image found, c++ ubuntu, architecture x86_64, check process, find installed, line 0, multiple processes, allowed memory, python run, drivers, unix timestamp, sql developer, script command, static vs, remote debugging, compile c, smtp connect, php ubuntu, signal strength, cpanel, port using, run c, something similar, php read, code windows, cron jobs, multiple source, machine using, make static, core dumped, dynamic memory, gcc compiler, nginx +, unix epoch, start c#, different user, argument supplied, directory java, socket client, 13 permission, compile run, dead, connection client, process exited, authenticating, opencl, linking static, line php, pointers c, limit exceeded, client socket, high resolution, simple c, java heap, python shell, unable execute, task manager, studio c++, opening browser, external process, r script, c++ library, macos, h file, vendor, server program, cpp files, development environment, managepy, monodevelop, reset peer, using ip, program running, simultaneous, query sql, tmp mysqlsock, script c#, uncaught reference, passenger nginx, write large, gd library, php python, make django, running program, many open, vbnet get, boost c++, file instead, tcp port, windows using, red, java send, windows c++, portable class, wait till, websphere 61, port communication, using command, org apache, every 5, python os, command windows, typo3, revert, program python, local mysql, trying write, write error, piped, c++ source, dumped, python cannot, sending large, using socket, multithreaded environment, usb device, max_execution_time, pydev, long running, python socket, godaddy, running command, compiling c++, nas, dynamically allocate, linux windows, exited, manual corresponds, execute java, unbuffered, fortran, eclipse c++, look like, joined, numpys, r package, memory warning, stop javascript, via https, error ubuntu, hanging, 16 bit, platforms, using tcp, base 64, serial data, doesnt fire, leaked, locate element, solaris, another directory, using subprocess, python package, python scripts, tcp sockets, real world, run eclipse, memory address, strlen, python memory, programs, php 53, address client, java tcp, 30 seconds, python cgi, pointer pointer, java tomcat, name already, conform, reduce memory, sql script, php7, network adapter, windows command, variables c++, mb, dual, data retrieved, open include, disconnected, access memory, time error, prompt using, line c, depend, 2 file, executing command, subprocess call, compile python, c++ console, intensive, java console, pause resume, start process, serial number, sprite kit, version python, cannot install, script python, file pdf, script server, script run, nonstatic field, getting time, android apps, server c#, release mode, java jar, console output, word count, c# thread, use try, program run, buffer size, rails javascript, errno 13, machine learning, execute query, directory error, process memory, static libraries, unterminated string, sending file, lua c, enough space, error installing, encoding issue, broken pipe, disk space, dos, path java, find main, executing php, write output, php socket, library path, get 2, c++ header, application without, python 26, 187, jobs, c++ 2010, variables values, protocol buffer, using opengl, iis 7, python kivy, execute sql, cannot run, selfsigned, library php, log files, print values, local time, process windows, undefined symbol, line arguments, execute multiple, programming using, executereader, tcp connections, tcp ip, gnu, correct use, ant build, application running, asset pipeline, trap, output php, apache tomcat, robust, socketerror, linker error, email address, apache 24, arduino, php set, error unrecognized, reliably, toolsjar, console input, symbols architecture, rvm install, denied error, alive, install pil, command php, argument error, run jar, crypto, unable run, cmd, inside c++, c++ libraries, pid, openmp, trying compile, ta ...

# %% [markdown]
# ### Authorization & Submission
# To submit assignment parts to Cousera platform, please, enter your e-mail and token into variables below. You can generate token on this programming assignment page. <b>Note:</b> Token expires 30 minutes after generation.

# %%
grader.status()
# Out:
# You want to submit these parts:
# Task TextPrepare:
#  sqlite php readonly
# creating multiple textboxes dynamically
# self one prefer javascript
# save php date...
# Task WordsTagsCount:
#  javascript,c#,java
# using,php,java...
# Task BagOfWords:
#  7...
# Task MultilabelClassification:
#  0	php
# 1	javascript
# 2
# 3	javascript,jquery
# 4	android
# 5	php,xml
# 6	json
# 7	java
# 8	python
# 9
# 10
# 11
# 12
# ...

# %%
STUDENT_EMAIL = 'zhoun@i2r.a-star.edu.sg' # EMAIL 
STUDENT_TOKEN = 'uP1WghJTcUkWYdT3' # TOKEN 
grader.status()
# Out:
# You want to submit these parts:
# Task TextPrepare:
#  sqlite php readonly
# creating multiple textboxes dynamically
# self one prefer javascript
# save php date...
# Task WordsTagsCount:
#  javascript,c#,java
# using,php,java...
# Task BagOfWords:
#  7...
# Task MultilabelClassification:
#  0	php
# 1	javascript
# 2
# 3	javascript,jquery
# 4	android
# 5	php,xml
# 6	json
# 7	java
# 8	python
# 9
# 10
# 11
# 12
# ...

# %% [markdown]
# If you want to submit these answers, run cell below

# %%
grader.submit(STUDENT_EMAIL, STUDENT_TOKEN)
# Out:
# Submitted to Coursera platform. See results on assignment page!
